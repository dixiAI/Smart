# %%
import pandas as pd
import numpy as np

# Variable declaration
#sheet_name1 = 'sheet1'
#sheet_name2 = 'comments'
#sheet_name3 = 'jobs'
#sheet_name4 = 'members'
#sheet_name5 = 'projects'
#sheet_name6 = 'membership'
#sheet_name7 = 'fonctions'
xls_file = pd.read_excel('/home/doris/Dropbox/SmartBE/complet2011-2015.xlsx',sheet_name="jobs")

# %%
xls_file
# Out:
#         IDprest  IDmember  IDclient  annee  mois  \
# 0        547534    157853     97782   2013     5
# 1        565255    171611     29007   2013     1
# 2        697556    204797     60928   2012     6
# 3        381625    173126    116989   2014     7
# 4        772334    198293    118627   2012     6
# 5        352433    186932    123200   2014    12
# 6        307993    194564    118633   2015     3
# 7        937387    169019     40599   2011     9
# 8        257092    169974     40287   2015     6
# 9        650329    179921    101505   2013     4
# 10        29068    203556    112176   2016    11
# 11       235138    202043     62602   2015     8
# 12       278322    158558    124849   2015     6
# 13       378081    203732    124055   2014     9
# 14        22162    203041    112367   2016    11
# 15        18457    165708    118498   2016    12
# 16       812974    187701    122211   2011    12
# 17       351085    168392    102343   2014     1
# ...

# %%
xls_file.to_csv('smart_jobs.csv')

# %%
#sheet_name4 = 'members'
xls_file_members = pd.read_excel('/home/doris/Dropbox/SmartBE/complet2011-2015.xlsx',sheet_name="members")
xls_file_members.to_csv('smart_members.csv')

# %%
xls_file_members
# Out:
#        IDmember  yearNaissance   zip1   zip2 idCountry1 idCountry2  \
# 0        179703           1968   5000   5000         BE         BE
# 1        183768           1969   1180   1180         BE         BE
# 2        174862           1980   1060   1060         BE         BE
# 3        181926           1967   1300   1300         BE         BE
# 4        199518           1977   1640   1640         BE         BE
# 5        177276           1980   1030   1030         BE         BE
# 6        178689           1981   1301   1301         BE         BE
# 7        141465           1965   2820   2820         BE         BE
# 8        148907           1983   1000   1000         BE         BE
# 9        170529           1976   1060   1060         BE         BE
# 10       195032           1984   1200   1200         BE         BE
# 11       190589           1961   1000   1000         BE         BE
# 12       157968           1963   4970   4970         BE         BE
# ...

# %%
#sheet_name5 = 'projects'
xls_file_projects = pd.read_excel('/home/doris/Dropbox/SmartBE/complet2011-2015.xlsx',sheet_name="projects")
xls_file_projects.to_csv('smart_projects.csv')

# %%
xls_file_projects
# Out:
#        IDproject                   projectName  \
# 0         122686              Forme et Couleur
# 1         109553                 Trompe l'Oeil
# 2         122828      On Top Level Managements
# 3         106006                  DOG SOlution
# 4         105969              Studio Entropica
# 5         122612                          BAVO
# 6         114765                    SkatDesign
# 7         112758                         PATIA
# 8         113023                 BUILD AT HOME
# 9         110956               A.M Traductions
# 10        104309                CC PHOTOGRAPHY
# 11        105319     Music for motion pictures
# 12        109930                       CHILSOU
# 13        104648             Surf your way out
# 14        107901                     VADU AMKA
# 15        105001                        FoxArt
# 16        103919                       ARTOUCH
# 17        116735                       N'Nache
# 18        105035                    ARBOGRIMPE
# ...

# %%
#sheet_name6 = 'membership'
xls_file_membership = pd.read_excel('/home/doris/Dropbox/SmartBE/complet2011-2015.xlsx',sheet_name="membership")
xls_file_membership.to_csv('smart_membership.csv')

# %%
xls_file_membership
# Out:
#        idProject  idMember  yearInscription  typemember
# 0         117912    191996             2012           3
# 1         119783    151415             2013           3
# 2         104954    199752             2016           2
# 3         123514    179463             2009           3
# 4         115088    156660             2012           1
# 5         113450    171149             2013           2
# 6         106022    146097             2016           1
# 7         123950    178793             2009           3
# 8         111230    134887             2016           3
# 9         123213    195866             2012           3
# 10        122877    179418             2009           2
# 11        107161    139883             2016           1
# 12        116573    174190             2012           3
# 13        121845    201309             2009           1
# 14        105870    133913             2016           1
# 15        112020    148786             2014           1
# ...

# %%
#sheet_name7 = 'fonctions'
xls_file_fonctions = pd.read_excel('/home/doris/Dropbox/SmartBE/complet2011-2015.xlsx',sheet_name="fonctions")
xls_file_fonctions.to_csv('smart_fonctions.csv')

# %%
xls_file_fonctions
# Out:
#       id  level  level1  level2  \
# 0    121      3     NaN   113.0
# 1    270      3     NaN   193.0
# 2      5      3     NaN     2.0
# 3     90      3     NaN    87.0
# 4    240      2   203.0     NaN
# 5     63      2     1.0     NaN
# 6    220      3     NaN   217.0
# 7    139      3     NaN   136.0
# 8    159      2   143.0     NaN
# 9    228      3     NaN   226.0
# 10    60      3     NaN    51.0
# 11   254      3     NaN   251.0
# 12   187      3     NaN   179.0
# 13    16      3     NaN     2.0
# 14    34      3     NaN    27.0
# 15   277      3     NaN   232.0
# 16     1      1     NaN     NaN
# 17    42      3     NaN    41.0
# 18   161      3     NaN   159.0
# 19    27      2     1.0     NaN
# 20   195      3     NaN   193.0
# 21    79      3     NaN    73.0
# 22   114      3     NaN   113.0
# 23   132      3     NaN   129.0
# 24   225      3     NaN   217.0
# 25   269      3     NaN   129.0
# 26    99      3     NaN    95.0
# 27   172      3     NaN   159.0
# ...
